# %%
import sys
sys.path.append(r'C:\Users\lwang\Documents\GitHub\DataAnalysis')

# %%
import numpy as np
import sys, os
from pathlib import Path
import pandas as pd
import copy
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go
from plotly.colors import n_colors
import math
import datetime as dt
from sklearn.metrics import r2_score
import plotly.colors
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu
from scipy.interpolate import griddata
from sklearn.linear_model import LinearRegression
import scipy
import importlib
import pickle

# ----- Internal Dependencies -------#
nb_dir = os.path.split(os.getcwd())[0]
sys.path.append("../..")
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from General import FileRead
from General import AccuracyMetrics
from General.GeneralFunctions import get_add_to_dict
from General import TableManipulations
from FeatureGeneration import GeneralFeatures
from General import FileWrite

from Plot.PdfHelper import PdfHelper
from Plot.PlotMaker import PlotMaker
# from Plot import Voltage_Plots
from Plot import PlotFunctions
# from Plot import AdHocPlots
# from Plot import Sim_Plots

# widget and notebook stuff
from ipywidgets import interact, fixed
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook"

# %%
import importlib.util

# Set up environment (e.g. sys.path)
assembler_folder = r'C:\Users\lwang\Documents\GitHub\DataAnalysis\AlgorithmAssembler'
top_folder = r'C:\Users\lwang\Documents\GitHub\DataAnalysis'

# Set up the module function to be tested. This is equivalent to from X.Y.Z import module_func, but avoid potential ImportError
background_func_file_path = os.path.join(assembler_folder,'Modules','glucoseModel','channel_gluc_current','time_varying_background.py')
background_func_name = os.path.relpath(background_func_file_path,top_folder).replace('.py','').replace(os.sep,'.')
background_func_spec = importlib.util.spec_from_file_location(background_func_name,background_func_file_path)
background_func_info = importlib.util.module_from_spec(background_func_spec)
background_func_spec.loader.exec_module(background_func_info)
background_func = getattr(background_func_info,'background_gamma_cdf_based')

sensitivity_func_file_path = os.path.join(assembler_folder,'Modules','glucoseModel','channel_dermis_gluc','time_varying_sensitivity.py')
sensitivity_func_name = os.path.relpath(sensitivity_func_file_path,top_folder).replace('.py','').replace(os.sep,'.')
sensitivity_func_spec = importlib.util.spec_from_file_location(sensitivity_func_name,sensitivity_func_file_path)
sensitivity_func_info = importlib.util.module_from_spec(sensitivity_func_spec)
sensitivity_func_spec.loader.exec_module(sensitivity_func_info)
sensitivity_func = getattr(sensitivity_func_info,'sensitivity_gamma_cdf_based')

# %% [markdown]
# load data

# %%
df=pd.read_csv(r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\agg_mfg_ref_sample_df_from17.csv')
df_orig=df.copy()
# Out:
# c:\Users\lwang\Documents\GitHub\AlgoVenv1\lib\site-packages\IPython\core\interactiveshell.py:3269: DtypeWarning:
#
# Columns (9,13,15) have mixed types.Specify dtype option on import or set low_memory=False.

# %% [markdown]
# Setting

# %%
training_group = ['eBlinq19c','eBlinq20','eBlinq22','eBlinq23','eBlinq25','eBlinqRingOverlay&NiMNA','iBlinqAcet','iBlinqFW231','iBlinqOverlay']
test_group = ['Pre-Piv-2-training']
all_training_channel = ['1','3','4']
training_time_window = [0.083,5]
training_chemistry = '2.6.11'
test_chemistry = '2.6.11'
iso_thresh = 20
params_bound = [
    [0,1e5],
    [1e-6,0.1],[1e-6,0.1],[1e-2,1e2],
    [0,1e3],[0,1e3],[1e-2,1e2],
    [1e-1,1e2],[1e-1,10],[1e-2,1e2],
]
col_for_optim = [
    'cur1','cur3','cur4','Chemistry',
    'time_from_start_featureGeneration','mag1_1007_featureGeneration','mag3_1007_featureGeneration','mag4_1007_featureGeneration',
    'Study','retro_model_output_s1_calculateGlucose','retro_model_output_s3_calculateGlucose','retro_model_output_s4_calculateGlucose'
]
ref_for_optim = 'acck'
col_for_optim.append(ref_for_optim)

# %%
def glucose_model(cur,features,params):
    background_params = params['background']
    sensitivity_params = params['sensitivity']
    glucose_current,_ = background_func(cur,features,background_params)
    dermis_gluc,sensitivity_info = sensitivity_func(glucose_current,features,sensitivity_params)
    sensitivity = sensitivity_info['sensitivity']
    return dermis_gluc, sensitivity

def params_list_to_dict(params_list,channel_str):
    params = {}
    background_params = {
        'feature_schema': {'mag_1007':f'mag{channel_str}_1007'},
        'sim_slope_background': {'value': params_list[0]},
        'sim_intercept_background_start': {'value': params_list[1]},
        'sim_intercept_background_end': {'value': params_list[2]},
        'sim_intercept_background_a': {'value': 1},
        'sim_intercept_background_loc': {'value': 0},
        'sim_intercept_background_beta': {'value': params_list[3]},
    }
    params['background'] = background_params
    sensitivity_params = {
        'feature_schema': {'mag_1007':f'mag{channel_str}_1007'},
        'sim_intercept_sensitivity_start': {'value': params_list[4]*1e-10},
        'sim_intercept_sensitivity_end': {'value': params_list[5]*1e-10},
        'sim_intercept_sensitivity_a': {'value': 1},
        'sim_intercept_sensitivity_loc': {'value': 0},
        'sim_intercept_sensitivity_beta': {'value': params_list[6]},
        'sim_slope_sensitivity_start': {'value': params_list[7]*1e-3},
        'sim_slope_sensitivity_end': {'value': params_list[8]*1e-3},
        'sim_slope_sensitivity_a': {'value': 1},
        'sim_slope_sensitivity_loc': {'value': 0},
        'sim_slope_sensitivity_beta': {'value': params_list[9]},
    }
    params['sensitivity'] = sensitivity_params
    return params

def mard(params_list,g,cur,features,channel_str):
    params = params_list_to_dict(params_list,channel_str)
    g_hat, _ = glucose_model(cur,features,params)    
    mard = g_hat.sub(g).abs().div(g).mean()
    return mard

def costFunc(params_list,g,cur,features,channel_str):
    params = params_list_to_dict(params_list,channel_str)
    g_hat, sensitivity = glucose_model(cur,features,params)
    error = g_hat.sub(g).div(g).mul(sensitivity).mul(1e3).abs().mean()
    return error

def callback_da(x,f,context=0):
    params_dict = params_list_to_dict(x,1)
    print(f'Cost function value is {f}, and parameters are {params_dict}')

# %%
df = df_orig[col_for_optim].copy()
df.rename(columns={
                'time_from_start_featureGeneration': 'time_from_start',
                'mag1_1007_featureGeneration': 'mag1_1007',
                'mag3_1007_featureGeneration': 'mag3_1007',
                'mag4_1007_featureGeneration': 'mag4_1007',
                'retro_model_output_s1_calculateGlucose': 'retro_model_output_s1',
                'retro_model_output_s3_calculateGlucose': 'retro_model_output_s3',
                'retro_model_output_s4_calculateGlucose': 'retro_model_output_s4',
                }, inplace=True)
all_results= {}
all_optim_params = {}
hypo_idx = df[ref_for_optim].le(100)
for ch_str in all_training_channel:
    print(f'Optmizing channel {ch_str}')
    this_result = []
    df[f'ad_s{ch_str}'] = df[f'retro_model_output_s{ch_str}'].sub(df[ref_for_optim]).abs()
    df[f'ard_s{ch_str}'] = df[f'ad_s{ch_str}'].div(df[ref_for_optim]).mul(100)
    df[f'iso_s{ch_str}'] = df[f'ard_s{ch_str}']
    df.loc[hypo_idx,f'iso_s{ch_str}'] = df.loc[hypo_idx,f'ad_s{ch_str}']
    col_for_optim_no_ysi_acck = list(df.columns)
    training_index = df[df['Study'].isin(training_group) & df['time_from_start'].between(training_time_window[0],training_time_window[1]) & 
                            df['Chemistry'].eq(training_chemistry)].index
    df_training = df.loc[training_index,col_for_optim_no_ysi_acck].dropna().reset_index(drop=True)
    valid_training_index = df[df['Study'].isin(training_group) & df['time_from_start'].between(training_time_window[0],training_time_window[1]) & 
                            df[f'iso_s{ch_str}'].le(iso_thresh) & df['Chemistry'].eq(training_chemistry)].index
    df_training_valid = df.loc[valid_training_index,col_for_optim_no_ysi_acck].dropna().reset_index(drop=True)
    print(f'Training data has shape {df_training.shape}')
    print(f'Training data has shape {df_training_valid.shape}')
    good_data_ratio = len(df_training_valid)/len(df_training)
    print(f'Ratio of good data is {good_data_ratio}')
    valid_test_index = df[df['Study'].isin(test_group) & df['time_from_start'].between(training_time_window[0],training_time_window[1]) & 
                            df[f'iso_s{ch_str}'].le(iso_thresh) & df['Chemistry'].eq(training_chemistry)].index
    df_test_valid = df.loc[valid_test_index,col_for_optim_no_ysi_acck].dropna().reset_index(drop=True)
    print(f'Test data has shape {df_test_valid.shape}')
    g_train = df_training_valid[ref_for_optim]
    features_train = df_training_valid[['time_from_start',f'mag{ch_str}_1007']]
    cur_train = df_training_valid[f'cur{ch_str}']

    g_test = df_test_valid[ref_for_optim]
    features_test = df_test_valid[['time_from_start',f'mag{ch_str}_1007']]
    cur_test = df_test_valid[f'cur{ch_str}']

    result = scipy.optimize.dual_annealing(mard,params_bound,callback=callback_da,args=(g_train,cur_train,features_train,ch_str),maxiter=int(1e3))

    this_result.append(mard(result.x,g_train,cur_train,features_train,ch_str))
    this_result.append(mard(result.x,g_test,cur_test,features_test,ch_str))

    params_dict = params_list_to_dict(result.x,ch_str)
    g_hat_train, _ = glucose_model(cur_train,features_train,params_dict) 
    g_hat_test, _ = glucose_model(cur_test,features_test,params_dict) 

    reg_train = LinearRegression().fit(g_train.values.reshape(-1,1), g_hat_train.values)
    this_result.append(reg_train.score(g_train.values.reshape(-1,1), g_hat_train.values))
    this_result.append(reg_train.coef_)
    this_result.append(reg_train.intercept_)           

    reg_test = LinearRegression().fit(g_test.values.reshape(-1,1), g_hat_test.values)
    this_result.append(reg_test.score(g_test.values.reshape(-1,1), g_hat_test.values))
    this_result.append(reg_test.coef_)
    this_result.append(reg_test.intercept_)

    all_optim_params[f'channel_{ch_str}'] = params_dict
    all_results[f'channel_{ch_str}'] = this_result
    
results_df = pd.DataFrame.from_dict(all_results)
results_df.to_csv(r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\optimize_time_varying_model_acckOnly_exp.csv',header=True)
with open (r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\all_optim_params_acckOnly_exp.p','wb') as fp:
    pickle.dump(all_optim_params,fp)
# Out:
# Optmizing channel 1
# Training data has shape (207677, 16)
# Training data has shape (153591, 16)
# Ratio of good data is 0.7395667310294352
# Test data has shape (104946, 16)
# Cost function value is 0.7223749998917891, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 68155.94344203174}, 'sim_intercept_background_start': {'value': 0.07962406514213702}, 'sim_intercept_background_end': {'value': 0.013744805541742648}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 67.53649924386147}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.942521810531616e-11}, 'sim_intercept_sensitivity_end': {'value': 4.441990278810263e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 27.149009511077747}, 'sim_slope_sensitivity_start': {'value': 0.09971786002678215}, 'sim_slope_sensitivity_end': {'value': 0.0025261668743921735}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 83.99030245158676}}}
# Cost function value is 0.7079641875856082, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value':
, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 38.48824907888342}}}
# Cost function value is 0.1910693083458298, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 8169.205523846673}, 'sim_intercept_background_start': {'value': 0.08141544389750793}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 26.011862593857302}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.1124534876916825e-08}, 'sim_intercept_sensitivity_end': {'value': 2.89418051480091e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 7.383601816114951}, 'sim_slope_sensitivity_start': {'value': 0.03590208104151064}, 'sim_slope_sensitivity_end': {'value': 0.0009904822665405732}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 66.76995882216842}}}
# Cost function value is 0.1904795768541389, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7749.106352602583}, 'sim_intercept_background_start': {'value': 0.08141544389750793}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 26.011862593857302}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.1124534876916825e-08}, 'sim_intercept_sensitivity_end': {'value': 2.89418051480091e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 7.383601816114951}, 'sim_slope_sensitivity_start': {'value': 0.03590208104151064}, 'sim_slope_sensitivity_end': {'value': 0.0009904822665405732}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 66.76995882216842}}}
# Cost function value is 0.19046606754976547, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7749.106352172916}, 'sim_intercept_background_start': {'value': 0.08145797976845542}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 26.011864414392}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.1124534871134495e-08}, 'sim_intercept_sensitivity_end': {'value': 2.8941804783935517e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 7.3836018243377834}, 'sim_slope_sensitivity_start': {'value': 0.0359020813493075}, 'sim_slope_sensitivity_end': {'value': 0.0009875427999354385}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 66.7699577798546}}}
# Cost function value is 0.18990992446797, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7259.785751711606}, 'sim_intercept_background_start': {'value': 0.017532210953684707}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.85637555723392}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.759110983442407e-09}, 'sim_intercept_sensitivity_end': {'value': 2.8941804783935517e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 90.40870159106966}, 'sim_slope_sensitivity_start': {'value': 0.09940658883411876}, 'sim_slope_sensitivity_end': {'value': 0.0009875427999354385}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.01297900296397}}}
# Cost function value is 0.18990820443966894, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7259.785751711606}, 'sim_intercept_background_start': {'value': 0.0396205870745355}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.85637555723392}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.759110983442407e-09}, 'sim_intercept_sensitivity_end': {'value': 2.8941804783935517e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 90.40870159106966}, 'sim_slope_sensitivity_start': {'value': 0.09940658883411876}, 'sim_slope_sensitivity_end': {'value': 0.0009875427999354385}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.01297900296397}}}
# Cost function value is 0.1898782026957825, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7259.7857512790315}, 'sim_intercept_background_start': {'value': 0.03964620607475723}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.85637546011431}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.759110983442407e-09}, 'sim_intercept_sensitivity_end': {'value': 2.894180436085132e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 90.40870159015145}, 'sim_slope_sensitivity_start': {'value': 0.09940658877014408}, 'sim_slope_sensitivity_end': {'value': 0.000983241663244362}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.01297959372663}}}
# Cost function value is 0.18976589551446996, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7178.996935277668}, 'sim_intercept_background_start': {'value': 0.03964620607475723}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.85637546011431}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.759110983442407e-09}, 'sim_intercept_sensitivity_end': {'value': 2.894180436085132e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 90.40870159015145}, 'sim_slope_sensitivity_start': {'value': 0.09940658877014408}, 'sim_slope_sensitivity_end': {'value': 0.000983241663244362}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.01297959372663}}}
# Cost function value is 0.18976583032490144, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7178.996935277668}, 'sim_intercept_background_start': {'value': 0.04051339511095772}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.85637546011431}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.759110983442407e-09}, 'sim_intercept_sensitivity_end': {'value': 2.894180436085132e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 90.40870159015145}, 'sim_slope_sensitivity_start': {'value': 0.09940658877014408}, 'sim_slope_sensitivity_end': {'value': 0.000983241663244362}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.01297959372663}}}
# Cost function value is 0.18976535769250488, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 7178.9969347134065}, 'sim_intercept_background_start': {'value': 0.04054393460195123}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.85637534282203}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.759110983436644e-09}, 'sim_intercept_sensitivity_end': {'value': 2.8941803880516916e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 90.40870159003899}, 'sim_slope_sensitivity_start': {'value': 0.09940658870027858}, 'sim_slope_sensitivity_end': {'value': 0.0009826512942877614}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.01298023433024}}}
# Cost function value is 0.18976409930021101, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 
, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 89.03207920022979}}}
# Cost function value is 0.1801043630409482, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 697.066470922764}, 'sim_intercept_background_start': {'value': 0.06846050744870738}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.49433569742242}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.4684310424421146e-08}, 'sim_intercept_sensitivity_end': {'value': 1.7785307481934486e-12}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 94.62461702936801}, 'sim_slope_sensitivity_start': {'value': 0.08479069342784934}, 'sim_slope_sensitivity_end': {'value': 0.0009634022640761506}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 89.03207920022979}}}
# Cost function value is 0.18010435842828812, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 697.066470922764}, 'sim_intercept_background_start': {'value': 0.06846050744870738}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.49433569742242}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 4.304690225900977e-08}, 'sim_intercept_sensitivity_end': {'value': 1.7785307481934486e-12}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 94.62461702936801}, 'sim_slope_sensitivity_start': {'value': 0.08479069342784934}, 'sim_slope_sensitivity_end': {'value': 0.0009634022640761506}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 89.03207920022979}}}
# Cost function value is 0.18010426996972687, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 697.0664705348348}, 'sim_intercept_background_start': {'value': 0.06845240155696093}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.4943361223059}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 4.304690225900977e-08}, 'sim_intercept_sensitivity_end': {'value': 1.7784914078933224e-12}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 94.62461702936801}, 'sim_slope_sensitivity_start': {'value': 0.084790693486345}, 'sim_slope_sensitivity_end': {'value': 0.0009636373784187862}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 89.03207873426376}}}
# ...
# Cost function value is 0.1873073885151031, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.63030383028672}, 'sim_intercept_background_start': {'value': 0.07883035757129067}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 73.52909120239659}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.12156383088485e-08}, 'sim_intercept_sensitivity_end': {'value': 2.5441974580823615e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7177653071437542}, 'sim_slope_sensitivity_start': {'value': 0.057739099530378105}, 'sim_slope_sensitivity_end': {'value': 0.0009656074692183299}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.44665655162385}}}
# Cost function value is 0.18730693975435925, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.63030383028672}, 'sim_intercept_background_start': {'value': 0.07883035757129067}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 73.52909120239659}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.12156383088485e-08}, 'sim_intercept_sensitivity_end': {'value': 2.523417125596643e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7177653071437542}, 'sim_slope_sensitivity_start': {'value': 0.057739099530378105}, 'sim_slope_sensitivity_end': {'value': 0.0009656074692183299}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.44665655162385}}}
# Cost function value is 0.18730674169248462, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.63030383028672}, 'sim_intercept_background_start': {'value': 0.07883035757129067}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 73.52909120239659}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.12156383088485e-08}, 'sim_intercept_sensitivity_end': {'value': 2.523417125596643e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7124963078361708}, 'sim_slope_sensitivity_start': {'value': 0.057739099530378105}, 'sim_slope_sensitivity_end': {'value': 0.0009656074692183299}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.44665655162385}}}
# Cost function value is 0.1873067178801397, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.630303511764795}, 'sim_intercept_background_start': {'value': 0.07883020233886746}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 73.529091202409}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.121563830827311e-08}, 'sim_intercept_sensitivity_end': {'value': 2.5234170608254643e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7124859777037003}, 'sim_slope_sensitivity_start': {'value': 0.057739099513856994}, 'sim_slope_sensitivity_end': {'value': 0.0009654765412420538}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.44665662767316}}}
# Cost function value is 0.18730671144835637, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.636948804865824}, 'sim_intercept_background_start': {'value': 0.07711911117383122}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 72.27678847905779}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.1215394338724676e-08}, 'sim_intercept_sensitivity_end': {'value': 2.52274334252304e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7124859777037003}, 'sim_slope_sensitivity_start': {'value': 0.057739099513856994}, 'sim_slope_sensitivity_end': {'value': 0.0009654765412420538}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.44665662767316}}}
# Cost function value is 0.18730671005414343, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.636947730725137}, 'sim_intercept_background_start': {'value': 0.07711832013992576}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 72.27678847905779}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.121539433789201e-08}, 'sim_intercept_sensitivity_end': {'value': 2.5227431279724583e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7124476972140036}, 'sim_slope_sensitivity_start': {'value': 0.05773909946944808}, 'sim_slope_sensitivity_end': {'value': 0.0009654727248504259}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.44665684971791}}}
# Cost function value is 0.18730666440891783, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.570803092312417}, 'sim_intercept_background_start': {'value': 0.0801676812984726}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 72.35746137565354}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.121539433789201e-08}, 'sim_intercept_sensitivity_end': {'value': 2.5227431279724583e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7124476972140036}, 'sim_slope_sensitivity_start': {'value': 0.05775100455680747}, 'sim_slope_sensitivity_end': {'value': 0.0009654727248504259}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.34676180450711}}}
# Cost function value is 0.18730665888542802, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.570803092312417}, 'sim_intercept_background_start': {'value': 0.027544735314120466}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 72.35746137565354}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.121539433789201e-08}, 'sim_intercept_sensitivity_end': {'value': 2.5227431279724583e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7124476972140036}, 'sim_slope_sensitivity_start': {'value': 0.05775100455680747}, 'sim_slope_sensitivity_end': {'value': 0.0009654727248504259}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.34676180450711}}}
# Cost function value is 0.1873066577629083, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 11.570802012620614}, 'sim_intercept_background_start': {'value': 0.027545490265777087}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 72.35746137010243}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.1215394335671565e-08}, 'sim_intercept_sensitivity_end': {'value': 2.522742912866765e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7124096415444682}, 'sim_slope_sensitivity_start': {'value': 0.05775100447354075}, 'sim_slope_sensitivity_end': {'value': 0.0009654443281211562}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.34676218475873}}}
# Cost function value is 0.1873033413319275, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 6.502348388719838}, 'sim_intercept_background_start': {'value': 0.0035865692126546824}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 72.42641855046696}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.120764287703412e-08}, 'sim_intercept_sensitivity_end': {'value': 2.617747397334324e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7139422225849421}, 'sim_slope_sensitivity_start': {'value': 0.05821807716335662}, 'sim_slope_sensitivity_end': {'value': 0.0009654443281211562}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.38849160398354}}}
# Cost function value is 0.18730331063203864, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 6.502348388719838}, 'sim_intercept_background_start': {'value': 0.0486041495259463}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 72.42641855046696}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.120764287703412e-08}, 'sim_intercept_sensitivity_end': {'value': 2.617747397334324e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7139422225849421}, 'sim_slope_sensitivity_start': {'value': 0.05821807716335662}, 'sim_slope_sensitivity_end': {'value': 0.0009654443281211562}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.38849160398354}}}
# Cost function value is 0.18730328541219857, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 6.502348388719838}, 'sim_intercept_background_start': {'value': 0.0486041495259463}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 63.02616810937649}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.120764287703412e-08}, 'sim_intercept_sensitivity_end': {'value': 2.617747397334324e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7139422225849421}, 'sim_slope_sensitivity_start': {'value': 0.05821807716335662}, 'sim_slope_sensitivity_end': {'value': 0.0009654443281211562}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.38849160398354}}}
# Cost function value is 0.18728978315551456, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 6.502348388719838}, 'sim_intercept_background_start': {'value': 0.0486041495259463}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 63.02616810937649}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.068689519795446e-08}, 'sim_intercept_sensitivity_end': {'value': 1.9668429688340554e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7139422225849421}, 'sim_slope_sensitivity_start': {'value': 0.05821807716335662}, 'sim_slope_sensitivity_end': {'value': 0.0009654443281211562}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.38849160398354}}}
# Cost function value is 0.18728948815283764, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 6.502348091010088}, 'sim_intercept_background_start': {'value': 0.048603524546014486}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 63.026168111643045}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.0686895200293016e-08}, 'sim_intercept_sensitivity_end': {'value': 1.9668429134319853e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 0.7139262604056901}, 'sim_slope_sensitivity_start': {'value': 0.058218077153495126}, 'sim_slope_sensitivity_end': {'value': 0.0009658550312682149}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 87.3884916570791}}}

# %%
all_optim_params
# Out:
# {'channel_1': {'background': {'feature_schema': {'mag_1007': 'mag1_1007'},
#    'sim_slope_background': {'value': 3.255088317600894},
#    'sim_intercept_background_start': {'value': 0.1},
#    'sim_intercept_background_end': {'value': 1e-06},
#    'sim_intercept_background_a': {'value': 1},
#    'sim_intercept_background_loc': {'value': 0},
#    'sim_intercept_background_beta': {'value': 28.56092513255245}},
#   'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'},
#    'sim_intercept_sensitivity_start': {'value': 3.1167638035980115e-08},
#    'sim_intercept_sensitivity_end': {'value': 6.505585951880404e-10},
#    'sim_intercept_sensitivity_a': {'value': 1},
#    'sim_intercept_sensitivity_loc': {'value': 0},
#    'sim_intercept_sensitivity_beta': {'value': 1.1466947555178915},
#    'sim_slope_sensitivity_start': {'value': 0.04403369869118811},
#    'sim_slope_sensitivity_end': {'value': 0.0009531986814646717},
#    'sim_slope_sensitivity_a': {'value': 1},
#    'sim_slope_sensitivity_loc': {'value': 0},
#    'sim_slope_sensitivity_beta': {'value': 78.25689443399058}}},
#  'channel_3': {'background': {'feature_schema': {'mag_1007': 'mag3_1007'},
#    'sim_slope_background': {'value': 5.691164853099426},
#    'sim_intercept_background_start': {'value': 0.0541590962140274},
#    'sim_intercept_background_end': {'value': 1e-06},
#    'sim_intercept_background_a': {'value': 1},
#    'sim_intercept_background_loc': {'value': 0},
#    'sim_intercept_background_beta': {'value': 25.335526266880454}},
#   'sensitivity': {'feature_schema': {'mag_1007': 'mag3_1007'},
#    'sim_intercept_sensitivity_start': {'value': 3.519958643864981e-08},
#    'sim_intercept_sensitivity_end': {'value': 1.264928769631305e-10},
#    'sim_intercept_sensitivity_a': {'value': 1},
#    'sim_intercept_sensitivity_loc': {'value': 0},
#    'sim_intercept_sensitivity_beta': {'value': 58.17769857814982},
#    'sim_slope_sensitivity_start': {'value': 0.001064797517363663},
#    'sim_slope_sensitivity_end': {'value': 0.0008708943863941376},
#    'sim_slope_sensitivity_a': {'value': 1},
#    'sim_slope_sensitivity_loc': {'value': 0},
#    'sim_slope_sensitivity_beta': {'value': 0.34498077833410196}}},
#  'channel_4': {'background': {'feature_schema': {'mag_1007': 'mag4_1007'},
#    'sim_slope_background': {'value': 6.502348091010088},
#    'sim_intercept_background_start': {'value': 0.048603524546014486},
#    'sim_intercept_background_end': {'value': 1e-06},
#    'sim_intercept_background_a': {'value': 1},
#    'sim_intercept_background_loc': {'value': 0},
#    'sim_intercept_background_beta': {'value': 63.026168111643045}},
#   'sensitivity': {'feature_schema': {'mag_1007': 'mag4_1007'},
#    'sim_intercept_sensitivity_start': {'value': 3.0686895200293016e-08},
#    'sim_intercept_sensitivity_end': {'value': 1.9668429134319853e-09},
#    'sim_intercept_sensitivity_a': {'value': 1},
#    'sim_intercept_sensitivity_loc': {'value': 0},
#    'sim_intercept_sensitivity_beta': {'value': 0.7139262604056901},
#    'sim_slope_sensitivity_start': {'value': 0.058218077153495126},
#    'sim_slope_sensitivity_end': {'value': 0.0009658550312682149},
#    'sim_slope_sensitivity_a': {'value': 1},
#    'sim_slope_sensitivity_loc': {'value': 0},
#    'sim_slope_sensitivity_beta': {'value': 87.3884916570791}}}}

# %%
with open (r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\all_optim_params.p','wb') as fp:
    pickle.dump(all_optim_params,fp)

# %%
# with open (r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\all_optim_params.p','rb') as fp:
#     all_optim_params2 = pickle.load(fp)

# %%
all_results

# %%
all_optim_params

# %%
import scipy.stats as dist
dist_info_sim_slope = dist.gamma(a=16,loc=0,scale=1/7061)
time_from_start = [0,0.08,0.25,0.5,1,2,5]
sim_slope_sensitivity = 0 + 1*dist_info_sim_slope.cdf(time_from_start)
print(sim_slope_sensitivity)

# %%
result

# %%
import pprint
pp = pprint.PrettyPrinter(depth=4)
params_dict = params_list_to_dict(result.x,1)
pp.pprint(params_dict)

# %%
params = params_list_to_dict(result.x,ch_str)
g_train_hat, sensitivity = glucose_model(cur_train,features_train,params)    
mard = g_train_hat.sub(g_train).abs().div(g_train).mean()
error = g_train_hat.sub(g_train).mul(sensitivity).abs().div(g_train).mean()

# %%
mard

# %%
error

# %%
sim_slope = g_train.div(cur_train).div(features_train['mag1_1007']).mean()
sim_slope

# %%
g_simple = cur_train.mul(features_train['mag1_1007']).mul(sim_slope)
g_simple.sub(g_train).abs().div(g_train).mean()

# %%
reg_simple = LinearRegression().fit(g_train.values.reshape(-1,1), g_simple.values)
print(reg_simple.score(g_train.values.reshape(-1,1), g_simple.values))
print(reg_simple.coef_)
print(reg_simple.intercept_)

# %%
params = params_list_to_dict(result.x,ch_str)
g_hat_train, _ = glucose_model(cur_train,features_train,params) 
g_hat_test, _ = glucose_model(cur_test,features_test,params) 
reg_train = LinearRegression().fit(g_train.values.reshape(-1,1), g_hat_train.values)
print(reg_train.score(g_train.values.reshape(-1,1), g_hat_train.values))
print(reg_train.coef_)
print(reg_train.intercept_)
