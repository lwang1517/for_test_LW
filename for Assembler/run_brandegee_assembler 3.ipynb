# %%
import sys, os
import importlib
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
import Brandegees

# %%
importlib.reload(Brandegees)
shrub = Brandegees.Brandegees()
wrapper_assembler_config = r"C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\brandegee configs\wrapper_assembler_config_eBlinq19c.yml"
shrub.load_config_and_run(wrapper_assembler_config)
# Out:
# creating log at: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\20240503_171055_602013.log
#
# -------------------------------------------------------------
# Starting log at 2024-05-03 17:10:55.818840.
# last tag -ncommits-commit:
# 	v0.9.1+14f.2022-183-gd4064fcf-dirty
# 	2024-05-02 17:00:14 -0700
#
# 2 submodules found
# AlgorithmAssembler e46cf1fe
# HiveProcessing/butterfly_client f32e422e
# logger level: 20
#
#
# Current Step: load_data_pickle
# Loading from pickle C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration\alg_out.zip
# loaded from C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration\alg_out.zip:
# 	sensor_map_df: 33 rows
# 	raw_data: 31 sensors
# 	all_sensor_data: 31 sensors
# 	aggregated_data: 7 keys: ['ysi', 'acck', 'Libre', 'Dexcom', 'model', 'biolinq', 'sensor_stats']
# 	tables_written: 1
# Current Step: generate_plots
# Plotting clean_alg_output
# Plots - generating clean_alg_output plots using clean_alg_output settings, by condition
#     No data slices selected for creating
# Plots - generating clean_alg_output plots using clean_alg_output settings
#     all sensor keys in map
# PDF created C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\clean_alg_plots.pdf
# Plotting glucose_for_slide
# Plots - generating glucose_for_slide plots using glucose_for_slide settings, by condition
#     No data slices selected for creating
# Plots - generating glucose_for_slide plots using glucose_for_slide settings
#     all sensor keys in map
# PDF created C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\glucose_plots.pdf
# Plotting 2021_summary_study_currents
# Plots - generating 2021_summary_study_currents plots using 2021_summary_study_currents settings, by condition
#     No data slices selected for creating
# Plots - generating 2021_summary_study_currents plots using 2021_summary_study_currents settings
#     all sensor keys in map
# Created file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.html
# PDF created C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\eBlinq19c_integration_cont\Plots\summary_study_signals.pdf
# Completed with no unrecoverable errors. Please review log anyway.
# 2024-05-03 17:12:10.340553. Closing log file.

# %%
importlib.reload(Brandegees)
shrub = Brandegees.Brandegees()
wrapper_assembler_config = r"C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\brandegee configs\wrapper_assembler_config_eBlinq19b.yml"
shrub.load_config_and_run(wrapper_assembler_config)

# %%
importlib.reload(Brandegees)
shrub = Brandegees.Brandegees()
wrapper_assembler_config = r"C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\brandegee configs\wrapper_assembler_config_eBlinq20.yml"
shrub.load_config_and_run(wrapper_assembler_config)
# Out:
# creating log at: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\20240505_184759_039947.log
#
# -------------------------------------------------------------
# Starting log at 2024-05-05 18:47:59.330996.
# last tag -ncommits-commit:
# 	v0.9.1+14f.2022-183-gd4064fcf-dirty
# 	2024-05-02 17:00:14 -0700
#
# 2 submodules found
# AlgorithmAssembler e46cf1fe
# HiveProcessing/butterfly_client f32e422e
# logger level: 20
#
#
# Current Step: read_sensor_map
# reading sensor map from C:\Users\lwang.VM-WINDOWS-PACK\OneDrive - Biolinq Inc\Documents - Clinical Data Analysis\Data\Aggregate\new architecture eBlinq14 onwards\sensor map collection\sensor_map_eBlinq20.xlsx
#     Keeping 10 of 10 columns from sensor map. Removing set()
#     No duplicate Sensor_Ids in map file.
# These 43 sensors found:
# ['br232570070099',
#  'br232570030038',
#  'br232570060111',
#  'br232570070055',
#  'br232650020146',
#  'br232650030044',
#  'br232650020103',
#  'sa232400040137',
#  'br232570070115',
#  'br232570060126',
#  'br232650020096',
#  'br232570040003',
#  'br232650020114',
#  'br232650040081',
#  'br232650020053',
#  'br232570030045',
#  'br232650020123',
#  'br232570070083',
#  'br232570060114',
#  'br232570040026',
#  'br232650040055',
#  'br232570030022',
#  'br232570060014',
#  'br232650040072',
#  'br232650020152',
#  'br232570050088',
#  'br232650040130',
#  'br232570070092',
#  'br232650040090',
#  'sa232400040153',
#  'br232650020132',
#  'br232650020005',
#  'br232570060104',
#  'br232570030004',
#  'br232650020029',
#  'br232570040061',
#  'br232650020075',
#  'br232570060134',
#  'br232650020161',
#  'sa232400040134',
#  'br232570060066',
#  'br232570060006',
#  'br232570060165']
# sensor_map_df now has len:43, columns: Index(['Chemistry', 'trim max timestamp', 'Subject ID', 'SN', 'Sensor_Id',
#        'Location', 'Time Zone', 'Device Observations', 'Grouping',
#        'trim min timestamp'],
#       dtype='object')
# Current Step: retrieve_clinical_data_using_sensor_map
#     retrieving 43: ['br232570070099', 'br232570030038', 'br232570060111', 'br232570070055', 'br232650020146', 'br232650030044', 'br232650020103', 'sa232400040137', 'br232570070115', 'br232570060126', 'br232650020096', 'br232570040003', 'br232650020114', 'br232650040081', 'br232650020053', 'br232570030045', 'br232650020123', 'br232570070083', 'br232570060114', 'br232570040026', 'br232650040055', 'br232570030022', 'br232570060014', 'br232650040072', 'br232650020152', 'br232570050088', 'br232650040130', 'br232570070092', 'br232650040090', 'sa232400040153', 'br232650020132', 'br232650020005', 'br232570060104', 'br232570030004', 'br232650020029', 'br232570040061', 'br232650020075', 'br232570060134', 'br232650020161', 'sa232400040134', 'br232570060066', 'br232570060006', 'br232570060165']
#     on 1 of 43
# sensor_id: br232570070099, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374779, queried attempt: 1.
# sensor_id: br232570030038, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374780, queried attempt: 1.
# sensor_id: br232570060111, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374781, queried attempt: 1.
# sensor_id: br232570070055, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374871, queried attempt: 1.
# sensor_id: br232650020146, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374870, queried attempt: 1.
# sensor_id: br232650030044, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374869, queried attempt: 1.
# sensor_id: br232650020103, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 375976, queried attempt: 1.
# sensor_id: sa232400040137, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374783, queried attempt: 1.
# sensor_id: br232570070115, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374782, queried attempt: 1.
# sensor_id: br232570060126, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 377795, queried attempt: 1.
#     on 11 of 43
# sensor_id: br232650020096, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 377797, queried attempt: 1.
# sensor_id: br232570040003, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 377796, queried attempt: 1.
# sensor_id: br232650020114, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 375977, queried attempt: 1.
# sensor_id: br232650040081, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 374868, queried attempt: 1.
# sensor_id: br232650020053, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 393816, queried attempt: 1.
# sensor_id: br232570030045, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 393802, queried attempt: 1.
# sensor_id: br232650020123, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 393801, queried attempt: 1.
# sensor_id: br232570070083, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 377994, queried attempt: 1.
# sensor_id: br232570060114, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 377981, queried attempt: 1.
# sensor_id: br232570040026, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 393815, queried attempt: 1.
#     on 21 of 43
# sensor_id: br232650040055, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 395571, queried attempt: 1.
# sensor_id: br232570030022, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 395570, queried attempt: 3.
# sensor_id: br232570060014, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 395573, queried attempt: 1.
# sensor_id: br232650040072, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 393841, queried attempt: 1.
# sensor_id: br232650020152, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 393843, queried attempt: 1.
# sensor_id: br232570050088, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 393842, queried attempt: 1.
# sensor_id: br232650040130, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 395572, queried attempt: 1.
# sensor_id: br232570070092, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 395581, queried attempt: 1.
# sensor_id: br232650040090, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384006, queried attempt: 1.
# sensor_id: sa232400040153, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384007, queried attempt: 1.
#     on 31 of 43
# sensor_id: br232650020132, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384008, queried attempt: 1.
# sensor_id: br232650020005, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 383980, queried attempt: 1.
# sensor_id: br232570060104, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 383979, queried attempt: 1.
# sensor_id: br232570030004, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 383978, queried attempt: 1.
# sensor_id: br232650020029, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 383975, queried attempt: 1.
# sensor_id: br232570040061, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 383976, queried attempt: 1.
# sensor_id: br232650020075, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 383977, queried attempt: 1.
# sensor_id: br232570060134, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384018, queried attempt: 1.
# sensor_id: br232650020161, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384019, queried attempt: 1.
# sensor_id: sa232400040134, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384020, queried attempt: 1.
#     on 41 of 43
# sensor_id: br232570060066, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384012, queried attempt: 1.
# sensor_id: br232570060006, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384013, queried attempt: 1.
# sensor_id: br232570060165, # datasets: 1, queried attempt: 1, hive_response: 200.
# dataset_id: 384014, queried attempt: 3.
# Current Step: format_for_alginput
#     43 sensors with data in all_sensor_data dictionary
# Current Step: convert_all_sensor_data_to_old_format
# Current Step: save_to_pickle
# saving data to pickle.. C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\data_cleaned.zip
# Current Step: run_algorithm_assembler
# running algorithm on br232570070099...
# running algorithm on br232570030038...
# running algorithm on br232570060111...
# running algorithm on br232570070055...
# running algorithm on br232650020146...
# running algorithm on br232650030044...
# running algorithm on br232650020103...
# running algorithm on sa232400040137...
# running algorithm on br232570070115...
# running algorithm on br232570060126...
# running algorithm on br232650020096...
# running algorithm on br232570040003...
# running algorithm on br232650020114...
# running algorithm on br232650040081...
# running algorithm on br232650020053...
# running algorithm on br232570030045...
# running algorithm on br232650020123...
# running algorithm on br232570070083...
# running algorithm on br232570060114...
# running algorithm on br232570040026...
# running algorithm on br232650040055...
# running algorithm on br232570030022...
# running algorithm on br232570060014...
# running algorithm on br232650040072...
# running algorithm on br232650020152...
# running algorithm on br232570050088...
# running algorithm on br232650040130...
# running algorithm on br232570070092...
# running algorithm on br232650040090...
# running algorithm on sa232400040153...
# running algorithm on br232650020132...
# running algorithm on br232650020005...
# running algorithm on br232570060104...
# running algorithm on br232570030004...
# running algorithm on br232650020029...
# running algorithm on br232570040061...
# running algorithm on br232650020075...
# running algorithm on br232570060134...
# running algorithm on br232650020161...
# running algorithm on sa232400040134...
# running algorithm on br232570060066...
# running algorithm on br232570060006...
# running algorithm on br232570060165...
# Current Step: pair_and_create_excel_report
# Performance Eval - data aggregation step for ref ysi
#  after limits on ysi output range, keeping 1402 of 1402 biolinq v ysi pairs
# Performance Eval - data aggregation step for ref acck
#  after limits on acck output range, keeping 2347 of 2347 biolinq v acck pairs
# Performance Eval - data aggregation step for ref SMBG
#     Skipping pairing for br232570070099; sensor data has no SMBG
#     Skipping pairing for br232570030038; sensor data has no SMBG
#     Skipping pairing for br232570060111; sensor data has no SMBG
#     Skipping pairing for br232570070055; sensor data has no SMBG
#     Skipping pairing for br232650020146; sensor data has no SMBG
#     Skipping pairing for br232650030044; sensor data has no SMBG
#     Skipping pairing for br232650020103; sensor data has no SMBG
#     Skipping pairing for sa232400040137; sensor data has no SMBG
#     Skipping pairing for br232570070115; sensor data has no SMBG
#     Skipping pairing for br232570060126; sensor data has no SMBG
#     Skipping pairing for br232650020096; sensor data has no SMBG
#     Skipping pairing for br232570040003; sensor data has no SMBG
#     Skipping pairing for br232650020114; sensor data has no SMBG
#     Skipping pairing for br232650040081; sensor data has no SMBG
#     Skipping pairing for br232650020053; sensor data has no SMBG
#     Skipping pairing for br232570030045; sensor data has no SMBG
#     Skipping pairing for br232650020123; sensor data has no SMBG
#     Skipping pairing for br232570070083; sensor data has no SMBG
#     Skipping pairing for br232570060114; sensor data has no SMBG
#     Skipping pairing for br232570040026; sensor data has no SMBG
#     Skipping pairing for br232650040055; sensor data has no SMBG
#     Skipping pairing for br232570030022; sensor data has no SMBG
#     Skipping pairing for br232570060014; sensor data has no SMBG
#     Skipping pairing for br232650040072; sensor data has no SMBG
#     Skipping pairing for br232650020152; sensor data has no SMBG
#     Skipping pairing for br232570050088; sensor data has no SMBG
#     Skipping pairing for br232650040130; sensor data has no SMBG
#     Skipping pairing for br232570070092; sensor data has no SMBG
#     Skipping pairing for br232650040090; sensor data has no SMBG
#     Skipping pairing for sa232400040153; sensor data has no SMBG
#     Skipping pairing for br232650020132; sensor data has no SMBG
#     Skipping pairing for br232650020005; sensor data has no SMBG
#     Skipping pairing for br232570060104; sensor data has no SMBG
#     Skipping pairing for br232570030004; sensor data has no SMBG
#     Skipping pairing for br232650020029; sensor data has no SMBG
#     Skipping pairing for br232570040061; sensor data has no SMBG
#     Skipping pairing for br232650020075; sensor data has no SMBG
#     Skipping pairing for br232570060134; sensor data has no SMBG
#     Skipping pairing for br232650020161; sensor data has no SMBG
#     Skipping pairing for sa232400040134; sensor data has no SMBG
#     Skipping pairing for br232570060066; sensor data has no SMBG
#     Skipping pairing for br232570060006; sensor data has no SMBG
#     Skipping pairing for br232570060165; sensor data has no SMBG
# aggregated pairs for biolinq vs SMBG is empty, skipping
# Performance Eval - data aggregation step for ref Libre
#     Skipping pairing for br232650040055; sensor data has no Libre
#     Skipping pairing for br232570030022; sensor data has no Libre
#     Skipping pairing for br232570060014; sensor data has no Libre
#  after limits on Libre output range, keeping 26425 of 26425 biolinq v Libre pairs
# Performance Eval - data aggregation step for ref Dexcom
#  after limits on Dexcom output range, keeping 85628 of 85628 biolinq v Dexcom pairs
#     Skipping aggregating of model for br232570070099 because no model in sensor_data
#     Skipping aggregating of model for br232570030038 because no model in sensor_data
#     Skipping aggregating of model for br232570060111 because no model in sensor_data
#     Skipping aggregating of model for br232570070055 because no model in sensor_data
#     Skipping aggregating of model for br232650020146 because no model in sensor_data
#     Skipping aggregating of model for br232650030044 because no model in sensor_data
#     Skipping aggregating of model for br232650020103 because no model in sensor_data
#     Skipping aggregating of model for sa232400040137 because no model in sensor_data
#     Skipping aggregating of model for br232570070115 because no model in sensor_data
#     Skipping aggregating of model for br232570060126 because no model in sensor_data
#     Skipping aggregating of model for br232650020096 because no model in sensor_data
#     Skipping aggregating of model for br232570040003 because no model in sensor_data
#     Skipping aggregating of model for br232650020114 because no model in sensor_data
#     Skipping aggregating of model for br232650040081 because no model in sensor_data
#     Skipping aggregating of model for br232650020053 because no model in sensor_data
#     Skipping aggregating of model for br232570030045 because no model in sensor_data
#     Skipping aggregating of model for br232650020123 because no model in sensor_data
#     Skipping aggregating of model for br232570070083 because no model in sensor_data
#     Skipping aggregating of model for br232570060114 because no model in sensor_data
#     Skipping aggregating of model for br232570040026 because no model in sensor_data
#     Skipping aggregating of model for br232650040055 because no model in sensor_data
#     Skipping aggregating of model for br232570030022 because no model in sensor_data
#     Skipping aggregating of model for br232570060014 because no model in sensor_data
#     Skipping aggregating of model for br232650040072 because no model in sensor_data
#     Skipping aggregating of model for br232650020152 because no model in sensor_data
#     Skipping aggregating of model for br232570050088 because no model in sensor_data
#     Skipping aggregating of model for br232650040130 because no model in sensor_data
#     Skipping aggregating of model for br232570070092 because no model in sensor_data
#     Skipping aggregating of model for br232650040090 because no model in sensor_data
#     Skipping aggregating of model for sa232400040153 because no model in sensor_data
#     Skipping aggregating of model for br232650020132 because no model in sensor_data
#     Skipping aggregating of model for br232650020005 because no model in sensor_data
#     Skipping aggregating of model for br232570060104 because no model in sensor_data
#     Skipping aggregating of model for br232570030004 because no model in sensor_data
#     Skipping aggregating of model for br232650020029 because no model in sensor_data
#     Skipping aggregating of model for br232570040061 because no model in sensor_data
#     Skipping aggregating of model for br232650020075 because no model in sensor_data
#     Skipping aggregating of model for br232570060134 because no model in sensor_data
#     Skipping aggregating of model for br232650020161 because no model in sensor_data
#     Skipping aggregating of model for sa232400040134 because no model in sensor_data
#     Skipping aggregating of model for br232570060066 because no model in sensor_data
#     Skipping aggregating of model for br232570060006 because no model in sensor_data
#     Skipping aggregating of model for br232570060165 because no model in sensor_data
# column "sensor_day not present, attempting to add..
# unable to extract ref pairs for 08-21-01-038 - br232570070099 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-045 - br232570070055 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-039 - br232650020103 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-041 - br232570060126 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-040 - br232650020114 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-043 - br232650020053 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-047 - br232570070083 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-052 - br232650040055 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-049 - br232650040072 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-048 - br232650040130 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-044 - br232650040090 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-051 - br232650020005 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-042 - br232650020029 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-046 - br232570060134 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-050 - br232570060066 acck vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-038 - br232570070099 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-045 - br232570070055 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-039 - br232650020103 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-041 - br232570060126 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-040 - br232650020114 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-043 - br232650020053 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-047 - br232570070083 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-052 - br232650040055 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-049 - br232650040072 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-048 - br232650040130 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-044 - br232650040090 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-051 - br232650020005 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-042 - br232650020029 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-046 - br232570060134 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-050 - br232570060066 Libre vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-038 - br232570070099 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-045 - br232570070055 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-039 - br232650020103 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-041 - br232570060126 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-040 - br232650020114 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-043 - br232650020053 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-047 - br232570070083 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-052 - br232650040055 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-049 - br232650040072 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-048 - br232650040130 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-044 - br232650040090 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-051 - br232650020005 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-042 - br232650020029 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-046 - br232570060134 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-050 - br232570060066 Dexcom vs {'YSIT': 'ysi'}
# unable to extract ref pairs for 08-21-01-038 - br232570070099 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-045 - br232570070055 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-039 - br232650020103 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-041 - br232570060126 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-040 - br232650020114 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-043 - br232650020053 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-047 - br232570070083 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-052 - br232650040055 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-049 - br232650040072 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-048 - br232650040130 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-044 - br232650040090 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-051 - br232650020005 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-042 - br232650020029 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-046 - br232570060134 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-050 - br232570060066 Libre vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-038 - br232570070099 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-045 - br232570070055 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-039 - br232650020103 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-041 - br232570060126 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-040 - br232650020114 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-043 - br232650020053 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-047 - br232570070083 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-052 - br232650040055 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-049 - br232650040072 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-048 - br232650040130 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-044 - br232650040090 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-051 - br232650020005 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-042 - br232650020029 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-046 - br232570060134 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-050 - br232570060066 Dexcom vs {'AcckT': 'acck'}
# unable to extract ref pairs for 08-21-01-038 - br232570070099 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-045 - br232570070055 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-039 - br232650020103 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-041 - br232570060126 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-040 - br232650020114 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-043 - br232650020053 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-047 - br232570070083 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-052 - br232650040055 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-049 - br232650040072 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-048 - br232650040130 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-044 - br232650040090 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-051 - br232650020005 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-042 - br232650020029 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-046 - br232570060134 Dexcom vs {'LibreT': 'Libre'}
# unable to extract ref pairs for 08-21-01-050 - br232570060066 Dexcom vs {'LibreT': 'Libre'}
# updating self.sensor_map with aggregated data
# Evaluating all data ...
# Generating charts to C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward.pdf
# Created file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_sensorid.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_sensorid.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_sensorid.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_sensorid.html
# clarke_sensorid is not a valid chart type to create
# Created file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_subject.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_subject.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_subject.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_clarke_subject.html
# clarke_subject is not a valid chart type to create
# Created file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_bias_overall.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_bias_overall.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_bias_overall.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_bias_overall.html
# alt_bland_altman_bias_overall is not a valid chart type to create
# Created file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_rd_overall.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_rd_overall.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_rd_overall.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward_alt_bland_altman_rd_overall.html
# alt_bland_altman_rd_overall is not a valid chart type to create
# PDF created C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\performance\sensor_allref_forward.pdf
#     creating pivot tables for dictionary for sensor_allref_forward.xlsx
#     creating ref comparison tables for dictionary for sensor_allref_forward.xlsx
#     writing Agreement Rate sheet for sensor_allref_forward.xlsx
# 	Writing Survival Details
# 	Writing icgm
# 	Writing Clarke vs each_ref
# 	Writing RoC Concurrence biolinq vs each_ref
# 	Writing Concurrence biolinq vs each_ref
# 	Writing sensor_map
# No data slices selected for creating
# No data_filters selected for creating
# No data meeting filter requirements.
# Finished creating all excel outputs.
# Current Step: save_to_pickle_excel
# saving data to pickle.. C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\alg_out.zip
# Current Step: generate_plots
# Plotting clean_alg_output
# Plots - generating clean_alg_output plots using clean_alg_output settings, by condition
#     No data slices selected for creating
# Plots - generating clean_alg_output plots using clean_alg_output settings
#     all sensor keys in map
# PDF created C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\clean_alg_plots.pdf
# Plotting glucose_for_slide
# Plots - generating glucose_for_slide plots using glucose_for_slide settings, by condition
#     No data slices selected for creating
# Plots - generating glucose_for_slide plots using glucose_for_slide settings
#     all sensor keys in map
# PDF created C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\glucose_plots.pdf
# Plotting 2021_summary_study_currents
# Plots - generating 2021_summary_study_currents plots using 2021_summary_study_currents settings, by condition
#     No data slices selected for creating
# Plots - generating 2021_summary_study_currents plots using 2021_summary_study_currents settings
#     all sensor keys in map
# Created file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# Adding to file: C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.html
# PDF created C:\Users\lwang.VM-WINDOWS-PACK\Documents\Simulation\eBlinq20_integration\Plots\summary_study_signals.pdf
# Completed with no unrecoverable errors. Please review log anyway.
# 2024-05-06 00:22:26.736582. Closing log file.
