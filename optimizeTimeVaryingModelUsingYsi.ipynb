# %%
import sys
sys.path.append(r'C:\Users\lwang\Documents\GitHub\DataAnalysis')

# %%
import numpy as np
import sys, os
from pathlib import Path
import pandas as pd
import copy
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go
from plotly.colors import n_colors
import math
import datetime as dt
from sklearn.metrics import r2_score
import plotly.colors
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu
from scipy.interpolate import griddata
from sklearn.linear_model import LinearRegression
import scipy
import importlib
import pickle

# ----- Internal Dependencies -------#
nb_dir = os.path.split(os.getcwd())[0]
sys.path.append("../..")
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from General import FileRead
from General import AccuracyMetrics
from General.GeneralFunctions import get_add_to_dict
from General import TableManipulations
from FeatureGeneration import GeneralFeatures
from General import FileWrite

from Plot.PdfHelper import PdfHelper
from Plot.PlotMaker import PlotMaker
# from Plot import Voltage_Plots
from Plot import PlotFunctions
# from Plot import AdHocPlots
# from Plot import Sim_Plots

# widget and notebook stuff
from ipywidgets import interact, fixed
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook"

# %%
import importlib.util

# Set up environment (e.g. sys.path)
assembler_folder = r'C:\Users\lwang\Documents\GitHub\DataAnalysis\AlgorithmAssembler'
top_folder = r'C:\Users\lwang\Documents\GitHub\DataAnalysis'

# Set up the module function to be tested. This is equivalent to from X.Y.Z import module_func, but avoid potential ImportError
background_func_file_path = os.path.join(assembler_folder,'Modules','glucoseModel','channel_gluc_current','time_varying_background.py')
background_func_name = os.path.relpath(background_func_file_path,top_folder).replace('.py','').replace(os.sep,'.')
background_func_spec = importlib.util.spec_from_file_location(background_func_name,background_func_file_path)
background_func_info = importlib.util.module_from_spec(background_func_spec)
background_func_spec.loader.exec_module(background_func_info)
background_func = getattr(background_func_info,'background_gamma_cdf_based')

sensitivity_func_file_path = os.path.join(assembler_folder,'Modules','glucoseModel','channel_dermis_gluc','time_varying_sensitivity.py')
sensitivity_func_name = os.path.relpath(sensitivity_func_file_path,top_folder).replace('.py','').replace(os.sep,'.')
sensitivity_func_spec = importlib.util.spec_from_file_location(sensitivity_func_name,sensitivity_func_file_path)
sensitivity_func_info = importlib.util.module_from_spec(sensitivity_func_spec)
sensitivity_func_spec.loader.exec_module(sensitivity_func_info)
sensitivity_func = getattr(sensitivity_func_info,'sensitivity_gamma_cdf_based')

# %% [markdown]
# load data

# %%
df=pd.read_csv(r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\agg_mfg_ref_sample_df_from17.csv')
df_orig=df.copy()
# Out:
# c:\Users\lwang\Documents\GitHub\AlgoVenv1\lib\site-packages\IPython\core\interactiveshell.py:3269: DtypeWarning:
#
# Columns (9,13,15) have mixed types.Specify dtype option on import or set low_memory=False.

# %% [markdown]
# Setting

# %%
training_group = ['eBlinq19c','eBlinq20','eBlinq22','eBlinq23','eBlinq25','eBlinqRingOverlay&NiMNA','iBlinqAcet','iBlinqFW231','iBlinqOverlay']
test_group = ['Pre-Piv-2-training']
all_training_channel = ['1','3','4']
training_time_window = [0.083,5]
training_chemistry = '2.6.11'
test_chemistry = '2.6.11'
iso_thresh = 20
params_bound = [
    [0,1e5],
    [1e-6,0.1],[1e-6,0.1],[1e-2,1e2],
    [0,1e3],[0,1e3],[1e-2,1e2],
    [1e-1,1e2],[1e-1,10],[1e-2,1e2],
]
col_for_optim = [
    'cur1','cur3','cur4','Chemistry',
    'time_from_start_featureGeneration','mag1_1007_featureGeneration','mag3_1007_featureGeneration','mag4_1007_featureGeneration',
    'Study','retro_model_output_s1_calculateGlucose','retro_model_output_s3_calculateGlucose','retro_model_output_s4_calculateGlucose','cgm_adj','ysi','acck'
]

# %%
def glucose_model(cur,features,params):
    background_params = params['background']
    sensitivity_params = params['sensitivity']
    glucose_current,_ = background_func(cur,features,background_params)
    dermis_gluc,sensitivity_info = sensitivity_func(glucose_current,features,sensitivity_params)
    sensitivity = sensitivity_info['sensitivity']
    return dermis_gluc, sensitivity

def params_list_to_dict(params_list,channel_str):
    params = {}
    background_params = {
        'feature_schema': {'mag_1007':f'mag{channel_str}_1007'},
        'sim_slope_background': {'value': params_list[0]},
        'sim_intercept_background_start': {'value': params_list[1]},
        'sim_intercept_background_end': {'value': params_list[2]},
        'sim_intercept_background_a': {'value': 1},
        'sim_intercept_background_loc': {'value': 0},
        'sim_intercept_background_beta': {'value': params_list[3]},
    }
    params['background'] = background_params
    sensitivity_params = {
        'feature_schema': {'mag_1007':f'mag{channel_str}_1007'},
        'sim_intercept_sensitivity_start': {'value': params_list[4]*1e-10},
        'sim_intercept_sensitivity_end': {'value': params_list[5]*1e-10},
        'sim_intercept_sensitivity_a': {'value': 1},
        'sim_intercept_sensitivity_loc': {'value': 0},
        'sim_intercept_sensitivity_beta': {'value': params_list[6]},
        'sim_slope_sensitivity_start': {'value': params_list[7]*1e-3},
        'sim_slope_sensitivity_end': {'value': params_list[8]*1e-3},
        'sim_slope_sensitivity_a': {'value': 1},
        'sim_slope_sensitivity_loc': {'value': 0},
        'sim_slope_sensitivity_beta': {'value': params_list[9]},
    }
    params['sensitivity'] = sensitivity_params
    return params

def mard(params_list,g,cur,features,channel_str):
    params = params_list_to_dict(params_list,channel_str)
    g_hat, _ = glucose_model(cur,features,params)    
    mard = g_hat.sub(g).abs().div(g).mean()
    return mard

def costFunc(params_list,g,cur,features,channel_str):
    params = params_list_to_dict(params_list,channel_str)
    g_hat, sensitivity = glucose_model(cur,features,params)
    error = g_hat.sub(g).div(g).mul(sensitivity).mul(1e3).abs().mean()
    return error

def callback_da(x,f,context=0):
    params_dict = params_list_to_dict(x,1)
    print(f'Cost function value is {f}, and parameters are {params_dict}')

# %%
df = df_orig[col_for_optim].copy()
df.rename(columns={
                'time_from_start_featureGeneration': 'time_from_start',
                'mag1_1007_featureGeneration': 'mag1_1007',
                'mag3_1007_featureGeneration': 'mag3_1007',
                'mag4_1007_featureGeneration': 'mag4_1007',
                'retro_model_output_s1_calculateGlucose': 'retro_model_output_s1',
                'retro_model_output_s3_calculateGlucose': 'retro_model_output_s3',
                'retro_model_output_s4_calculateGlucose': 'retro_model_output_s4',
                }, inplace=True)
all_results= {}
all_optim_params = {}
time_idx_using_ysi = df['time_from_start'].between(0.083,1,inclusive='right')
df.loc[time_idx_using_ysi,'cgm_adj'] = df.loc[time_idx_using_ysi,'ysi']
df.loc[time_idx_using_ysi,'cgm_adj'] = df.loc[time_idx_using_ysi,'acck']
hypo_idx = df['cgm_adj'].le(100)
for ch_str in all_training_channel:
    print(f'Optmizing channel {ch_str}')
    this_result = []
    df[f'ad_s{ch_str}'] = df[f'retro_model_output_s{ch_str}'].sub(df['cgm_adj']).abs()
    df[f'ard_s{ch_str}'] = df[f'ad_s{ch_str}'].div(df['cgm_adj']).mul(100)
    df[f'iso_s{ch_str}'] = df[f'ard_s{ch_str}']
    df.loc[hypo_idx,f'iso_s{ch_str}'] = df.loc[hypo_idx,f'ad_s{ch_str}']
    col_for_optim_no_ysi_acck = list(df.columns)
    col_for_optim_no_ysi_acck.remove('ysi')
    col_for_optim_no_ysi_acck.remove('acck')
    training_index = df[df['Study'].isin(training_group) & df['time_from_start'].between(training_time_window[0],training_time_window[1]) & 
                            df['Chemistry'].eq(training_chemistry)].index
    df_training = df.loc[training_index,col_for_optim_no_ysi_acck].dropna().reset_index(drop=True)
    valid_training_index = df[df['Study'].isin(training_group) & df['time_from_start'].between(training_time_window[0],training_time_window[1]) & 
                            df[f'iso_s{ch_str}'].le(iso_thresh) & df['Chemistry'].eq(training_chemistry)].index
    df_training_valid = df.loc[valid_training_index,col_for_optim_no_ysi_acck].dropna().reset_index(drop=True)
    print(f'Training data has shape {df_training.shape}')
    print(f'Training data has shape {df_training_valid.shape}')
    good_data_ratio = len(df_training_valid)/len(df_training)
    print(f'Ratio of good data is {good_data_ratio}')
    valid_test_index = df[df['Study'].isin(test_group) & df['time_from_start'].between(training_time_window[0],training_time_window[1]) & 
                            df[f'iso_s{ch_str}'].le(iso_thresh) & df['Chemistry'].eq(training_chemistry)].index
    df_test_valid = df.loc[valid_test_index,col_for_optim_no_ysi_acck].dropna().reset_index(drop=True)
    print(f'Test data has shape {df_test_valid.shape}')
    g_train = df_training_valid['cgm_adj']
    features_train = df_training_valid[['time_from_start',f'mag{ch_str}_1007']]
    cur_train = df_training_valid[f'cur{ch_str}']

    g_test = df_test_valid['cgm_adj']
    features_test = df_test_valid[['time_from_start',f'mag{ch_str}_1007']]
    cur_test = df_test_valid[f'cur{ch_str}']

    result = scipy.optimize.dual_annealing(mard,params_bound,callback=callback_da,args=(g_train,cur_train,features_train,ch_str),maxiter=int(1e3))

    this_result.append(mard(result.x,g_train,cur_train,features_train,ch_str))
    this_result.append(mard(result.x,g_test,cur_test,features_test,ch_str))

    params_dict = params_list_to_dict(result.x,ch_str)
    g_hat_train, _ = glucose_model(cur_train,features_train,params_dict) 
    g_hat_test, _ = glucose_model(cur_test,features_test,params_dict) 

    reg_train = LinearRegression().fit(g_train.values.reshape(-1,1), g_hat_train.values)
    this_result.append(reg_train.score(g_train.values.reshape(-1,1), g_hat_train.values))
    this_result.append(reg_train.coef_)
    this_result.append(reg_train.intercept_)           

    reg_test = LinearRegression().fit(g_test.values.reshape(-1,1), g_hat_test.values)
    this_result.append(reg_test.score(g_test.values.reshape(-1,1), g_hat_test.values))
    this_result.append(reg_test.coef_)
    this_result.append(reg_test.intercept_)

    all_optim_params[f'channel_{ch_str}'] = params_dict
    all_results[f'channel_{ch_str}'] = this_result
    
results_df = pd.DataFrame.from_dict(all_results)
results_df.to_csv(r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\optimize_time_varying_model_ysi_exp.csv',header=True)
with open (r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\all_optim_params_ysi_exp.p','wb') as fp:
    pickle.dump(all_optim_params,fp)
# Out:
# Optmizing channel 1
# Training data has shape (2904358, 16)
# Training data has shape (2141665, 16)
# Ratio of good data is 0.7373970426510782
# Test data has shape (665739, 16)
# Cost function value is 1.2701026272649465, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 39351.291178025305}, 'sim_intercept_background_start': {'value': 0.040673860571795534}, 'sim_intercept_background_end': {'value': 0.04176232067175514}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 66.45141372783138}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 1.875536291152239e-08}, 'sim_intercept_sensitivity_end': {'value': 9.682970900982618e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.236102804076205}, 'sim_slope_sensitivity_start': {'value': 0.021949984015044954}, 'sim_slope_sensitivity_end': {'value': 0.002606171488122014}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 92.24952528828496}}}
# Cost function value is 0.7346685965401578, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 42873.14012018964}, 'sim_intercept_background_start': {'value': 0.03994318551643858}, 'sim_intercept_background_end': {'value': 0.08359716168864736}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 1.1927945394363724}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 2.9930670468509195e-08}, 'sim_intercept_sensitivity_end': {'value': 2.3084523516893387e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.930186557851595}, 'sim_slope_sensitivity_start': {'value': 0.0560604287457839}, 'sim_slope_sensitivity_end': {'value': 0.0013592470675671113}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 61.93853954323367}}}
# Cost function value is 0.27274031818940075, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 42873.14010867542}, 'sim_intercept_background_start': {'value': 1e-06}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 1.1376978450280637}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 2.993067046765316e-08}, 'sim_intercept_sensitivity_end': {'value': 2.308449697278417e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.930186674075706}, 'sim_slope_sensitivity_start': {'value': 0.056060428734104405}, 'sim_slope_sensitivity_end': {'value': 0.0012250486688765482}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 61.9385391662085}}}
# Cost function value is 0.2723929579361108, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 2095.4117770874873}, 'sim_intercept_background_start': {'value': 0.06993019594530456}, 'sim_intercept_background_end': {'value': 0.014982811130406474}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.02507995306527}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 2.6963869558274747e-08}, 'sim_intercept_sensitivity_end': {'value': 1.3818164881132544e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 21.641948749309133}, 'sim_slope_sensitivity_start': {'value': 0.09147492002401657}, 'sim_slope_sensitivity_end': {'value': 0.0007985041791219437}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 68.20091003795385}}}
# Cost function value is 0.18736453203876527, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 2095.4117760200224}, 'sim_intercept_background_start': {'value': 0.0699284175629145}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 64.02507996205433}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 2.6963869558513852e-08}, 'sim_intercept_sensitivity_end': {'value': 1.3818165411373136e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 21.641948688134615}, 'sim_slope_sensitivity_start': {'value': 0.09147492012961823}, 'sim_slope_sensitivity_end': {'value': 0.0009356579335901219}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 68.20090902188932}}}
# Cost function value is 0.18688642326165325, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1405.011468584562}, 'sim_intercept_background_start': {'value': 0.06653438959994887}, 'sim_intercept_background_end': {'value': 0.0004649225438740069}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 84.28839423887577}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.014342026251373e-08}, 'sim_intercept_sensitivity_end': {'value': 6.311390433257771e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.87958330050318}, 'sim_slope_sensitivity_start': {'value': 0.007113648230101552}, 'sim_slope_sensitivity_end': {'value': 0.0009527433551617243}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347361457063}}}
# Cost function value is 0.18688415450842472, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1405.5852756651002}, 'sim_intercept_background_start': {'value': 0.049821122493122455}, 'sim_intercept_background_end': {'value': 0.0004649225438740069}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 36.142559281886996}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.014342026251373e-08}, 'sim_intercept_sensitivity_end': {'value': 6.311390433257771e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.87958330050318}, 'sim_slope_sensitivity_start': {'value': 0.007113648230101552}, 'sim_slope_sensitivity_end': {'value': 0.0009527433551617243}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347361457063}}}
# Cost function value is 0.18686689976609114, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1405.5852756651002}, 'sim_intercept_background_start': {'value': 0.049821122493122455}, 'sim_intercept_background_end': {'value': 0.0004649225438740069}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 36.142559281886996}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.367046047954639e-08}, 'sim_intercept_sensitivity_end': {'value': 6.090970492540533e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.87958330050318}, 'sim_slope_sensitivity_start': {'value': 0.007113648230101552}, 'sim_slope_sensitivity_end': {'value': 0.0009527433551617243}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347361457063}}}
# Cost function value is 0.1868668208041272, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1405.5852756651002}, 'sim_intercept_background_start': {'value': 0.049821122493122455}, 'sim_intercept_background_end': {'value': 0.0004649225438740069}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 36.142559281886996}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.367046047954639e-08}, 'sim_intercept_sensitivity_end': {'value': 6.090970492540533e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.14572920936504}, 'sim_slope_sensitivity_start': {'value': 0.0069571268204094905}, 'sim_slope_sensitivity_end': {'value': 0.0009527433551617243}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347361457063}}}
# Cost function value is 0.18623077064306415, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1405.5852754192363}, 'sim_intercept_background_start': {'value': 0.0498368048639003}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 36.142559237554515}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.367046047963165e-08}, 'sim_intercept_sensitivity_end': {'value': 6.090970229688603e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.145729197740774}, 'sim_slope_sensitivity_start': {'value': 0.006957126672170727}, 'sim_slope_sensitivity_end': {'value': 0.0009367605281312116}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.953473671052926}}}
# Cost function value is 0.18622863298605769, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.3855781424645}, 'sim_intercept_background_start': {'value': 0.0498368048639003}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 36.142559237554515}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.367046047963165e-08}, 'sim_intercept_sensitivity_end': {'value': 6.090970229688603e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.145729197740774}, 'sim_slope_sensitivity_start': {'value': 0.006957126672170727}, 'sim_slope_sensitivity_end': {'value': 0.0009367605281312116}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.953473671052926}}}
# Cost function value is 0.1862283199934682, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.3855781424645}, 'sim_intercept_background_start': {'value': 0.058942467108603486}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 36.142559237554515}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.367046047963165e-08}, 'sim_intercept_sensitivity_end': {'value': 6.090970229688603e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.145729197740774}, 'sim_slope_sensitivity_start': {'value': 0.006957126672170727}, 'sim_slope_sensitivity_end': {'value': 0.0009367605281312116}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.953473671052926}}}
# Cost function value is 0.1861591266759984, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.3855781424645}, 'sim_intercept_background_start': {'value': 0.058942467108603486}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 38.37979113198323}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.433521830831015e-08}, 'sim_intercept_sensitivity_end': {'value': 4.59528519416026e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.145729197740774}, 'sim_slope_sensitivity_start': {'value': 0.006957126672170727}, 'sim_slope_sensitivity_end': {'value': 0.0009367605281312116}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.953473671052926}}}
# Cost function value is 0.18615910414058134, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.3855781424645}, 'sim_intercept_background_start': {'value': 0.058942467108603486}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 38.37979113198323}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.433521830831015e-08}, 'sim_intercept_sensitivity_end': {'value': 4.59528519416026e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.00858036195873}, 'sim_slope_sensitivity_start': {'value': 0.006957126672170727}, 'sim_slope_sensitivity_end': {'value': 0.0009367605281312116}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.953473671052926}}}
# Cost function value is 0.18615910250637616, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.3855781424645}, 'sim_intercept_background_start': {'value': 0.058942467108603486}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 38.37979113198323}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.433521830831015e-08}, 'sim_intercept_sensitivity_end': {'value': 4.59528519416026e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.00858036195873}, 'sim_slope_sensitivity_start': {'value': 0.006686374321538017}, 'sim_slope_sensitivity_end': {'value': 0.0009367605281312116}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.953473671052926}}}
# Cost function value is 0.1861573492355142, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.3855778462907}, 'sim_intercept_background_start': {'value': 0.05895108960428292}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 38.3797911066977}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.433521830853436e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595285063420699e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.008580307513334}, 'sim_slope_sensitivity_start': {'value': 0.006686374329916044}, 'sim_slope_sensitivity_end': {'value': 0.0009377588087626411}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347363302648}}}
# Cost function value is 0.1861569984447438, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.0246630245674}, 'sim_intercept_background_start': {'value': 0.05895108960428292}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 38.3797911066977}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.433521830853436e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595285063420699e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 20.008580307513334}, 'sim_slope_sensitivity_start': {'value': 0.006686374329916044}, 'sim_slope_sensitivity_end': {'value': 0.0009377588087626411}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347363302648}}}
# Cost function value is 0.18615578033648028, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.0246630245674}, 'sim_intercept_background_start': {'value': 0.007741177577864771}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.07529985692917}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.211904640853853e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595285063420699e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121670613886872}, 'sim_slope_sensitivity_start': {'value': 0.006686374329916044}, 'sim_slope_sensitivity_end': {'value': 0.0009377588087626411}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347363302648}}}
# Cost function value is 0.1861554710468835, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.0246630245674}, 'sim_intercept_background_start': {'value': 0.007741177577864771}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.07529985692917}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.211904640853853e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595285063420699e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121670613886872}, 'sim_slope_sensitivity_start': {'value': 0.0031047091324704528}, 'sim_slope_sensitivity_end': {'value': 0.0009377588087626411}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347363302648}}}
# Cost function value is 0.18615547055967255, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1403.0246620558876}, 'sim_intercept_background_start': {'value': 0.0077680755061940365}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.07529984582694}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.21190464088161e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595284601012848e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121669559175086}, 'sim_slope_sensitivity_start': {'value': 0.003104709493292938}, 'sim_slope_sensitivity_end': {'value': 0.0009377398072956701}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347351090196}}}
# Cost function value is 0.18615021003925333, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1397.6121958630683}, 'sim_intercept_background_start': {'value': 0.0077680755061940365}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.07529984582694}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.21190464088161e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595284601012848e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121669559175086}, 'sim_slope_sensitivity_start': {'value': 0.003104709493292938}, 'sim_slope_sensitivity_end': {'value': 0.0009377398072956701}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347351090196}}}
# Cost function value is 0.1861499733408578, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1397.6121958630683}, 'sim_intercept_background_start': {'value': 0.016587144228043665}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 39.07529984582694}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.21190464088161e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595284601012848e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121669559175086}, 'sim_slope_sensitivity_start': {'value': 0.003104709493292938}, 'sim_slope_sensitivity_end': {'value': 0.0009377398072956701}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347351090196}}}
# Cost function value is 0.1861498803424246, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1397.6121958630683}, 'sim_intercept_background_start': {'value': 0.016587144228043665}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 35.706837011918246}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.21190464088161e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595284601012848e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121669559175086}, 'sim_slope_sensitivity_start': {'value': 0.003104709493292938}, 'sim_slope_sensitivity_end': {'value': 0.0009377398072956701}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347351090196}}}
# Cost function value is 0.18614984830044926, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1397.6121958630683}, 'sim_intercept_background_start': {'value': 0.016587144228043665}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 35.706837011918246}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.358190940850887e-08}, 'sim_intercept_sensitivity_end': {'value': 4.595284601012848e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121669559175086}, 'sim_slope_sensitivity_start': {'value': 0.003104709493292938}, 'sim_slope_sensitivity_end': {'value': 0.0009377398072956701}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347351090196}}}
# Cost function value is 0.18612358498562928, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1397.6121958630683}, 'sim_intercept_background_start': {'value': 0.016587144228043665}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 35.706837011918246}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.358190940850887e-08}, 'sim_intercept_sensitivity_end': {'value': 4.015560072152266e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121669559175086}, 'sim_slope_sensitivity_start': {'value': 0.003104709493292938}, 'sim_slope_sensitivity_end': {'value': 0.0009377398072956701}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.95347351090196}}}
# Cost function value is 0.1861233608710273, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1397.6121955773074}, 'sim_intercept_background_start': {'value': 0.01659611237061146}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 35.70683700421034}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 6.358190940868591e-08}, 'sim_intercept_sensitivity_end': {'value': 4.015559943888647e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 13.121669228544254}, 'sim_slope_sensitivity_start': {'value': 0.0031047096120465772}, 'sim_slope_sensitivity_end': {'value': 0.0009380914436676325}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 46.953473476433466}}}
# Cost function value is 0.1861164315781088, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.395551709269}, 'sim_intercept_background_start': {'value': 0.0829192200251557}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 44.35768577784969}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.965855660603329e-08}, 'sim_intercept_sensitivity_end': {'value': 3.5909628389367983e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 50.95880465962217}, 'sim_slope_sensitivity_start': {'value': 0.0026077805955042723}, 'sim_slope_sensitivity_end': {'value': 0.0009380914436676325}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 49.03548131945515}}}
# Cost function value is 0.18611201409990288, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.395551709269}, 'sim_intercept_background_start': {'value': 0.0829192200251557}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 44.35768577784969}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.965855660603329e-08}, 'sim_intercept_sensitivity_end': {'value': 3.5909628389367983e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.62499222600953}, 'sim_slope_sensitivity_start': {'value': 0.011876147499231684}, 'sim_slope_sensitivity_end': {'value': 0.0009380914436676325}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 49.03548131945515}}}
# Cost function value is 0.18611189875014253, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.395551709269}, 'sim_intercept_background_start': {'value': 0.0829192200251557}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 44.35768577784969}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.965855660603329e-08}, 'sim_intercept_sensitivity_end': {'value': 3.5909628389367983e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.62499222600953}, 'sim_slope_sensitivity_start': {'value': 0.011876147499231684}, 'sim_slope_sensitivity_end': {'value': 0.0009380914436676325}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.1061203506056}}}
# Cost function value is 0.18611171353036118, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.3955514422519}, 'sim_intercept_background_start': {'value': 0.08292389661184979}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 44.35768575344168}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.965855660603329e-08}, 'sim_intercept_sensitivity_end': {'value': 3.5909627206926863e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.624992230450395}, 'sim_slope_sensitivity_start': {'value': 0.01187614745333489}, 'sim_slope_sensitivity_end': {'value': 0.0009384063418848212}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.106120349968805}}}
# Cost function value is 0.18610688918170076, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.3955514422519}, 'sim_intercept_background_start': {'value': 0.07659775087502887}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 48.628126730092994}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.855055764110857e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4696811995861937e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.624992230450395}, 'sim_slope_sensitivity_start': {'value': 0.01187614745333489}, 'sim_slope_sensitivity_end': {'value': 0.0009384063418848212}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.106120349968805}}}
# Cost function value is 0.1861068856369363, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.3955514422519}, 'sim_intercept_background_start': {'value': 0.07659775087502887}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 48.628126730092994}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.855055764110857e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4696811995861937e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.85569511080839}, 'sim_slope_sensitivity_start': {'value': 0.01187614745333489}, 'sim_slope_sensitivity_end': {'value': 0.0009384063418848212}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.106120349968805}}}
# Cost function value is 0.18610662715664889, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.3955514422519}, 'sim_intercept_background_start': {'value': 0.07659775087502887}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 48.628126730092994}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.855055764110857e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4696811995861937e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.85569511080839}, 'sim_slope_sensitivity_start': {'value': 0.009817847146744788}, 'sim_slope_sensitivity_end': {'value': 0.0009384063418848212}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.106120349968805}}}
# Cost function value is 0.18610660930402417, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1402.3955511748738}, 'sim_intercept_background_start': {'value': 0.07660062601770318}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 48.62812671551266}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.855055764110857e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4696810801161442e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.85569511468507}, 'sim_slope_sensitivity_start': {'value': 0.009817847164495692}, 'sim_slope_sensitivity_end': {'value': 0.0009385032975140781}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.10612029709366}}}
# Cost function value is 0.18609530346606987, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1398.2329011582333}, 'sim_intercept_background_start': {'value': 0.025342357190519527}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 49.22465769187314}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.8446392868597154e-08}, 'sim_intercept_sensitivity_end': {'value': 3.1930936627938083e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 48.29574146943158}, 'sim_slope_sensitivity_start': {'value': 0.016710790964028697}, 'sim_slope_sensitivity_end': {'value': 0.0009385032975140781}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.1495416141322}}}
# Cost function value is 0.18609525556580697, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1398.2329011582333}, 'sim_intercept_background_start': {'value': 0.025342357190519527}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 49.22465769187314}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.8446392868597154e-08}, 'sim_intercept_sensitivity_end': {'value': 3.1930936627938083e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 50.310684131950346}, 'sim_slope_sensitivity_start': {'value': 0.016710790964028697}, 'sim_slope_sensitivity_end': {'value': 0.0009385032975140781}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.1495416141322}}}
# Cost function value is 0.18609522679895898, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1398.2329008826823}, 'sim_intercept_background_start': {'value': 0.025349247900857696}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 49.224657677820694}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.844639286859353e-08}, 'sim_intercept_sensitivity_end': {'value': 3.193093542176965e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 50.310684139684774}, 'sim_slope_sensitivity_start': {'value': 0.016710790661374104}, 'sim_slope_sensitivity_end': {'value': 0.0009386273555315091}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 50.14954198539564}}}
# Cost function value is 0.18608319874106619, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1296.7098257610196}, 'sim_intercept_background_start': {'value': 0.04694127860989919}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 45.913185910149075}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.551909337285906e-08}, 'sim_intercept_sensitivity_end': {'value': 3.860955652579378e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 80.70060639496586}, 'sim_slope_sensitivity_start': {'value': 0.02911713566266699}, 'sim_slope_sensitivity_end': {'value': 0.0009386273555315091}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 47.04900629761081}}}
# Cost function value is 0.18608021136212607, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1296.7098257610196}, 'sim_intercept_background_start': {'value': 0.08457740159267652}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 45.913185910149075}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.551909337285906e-08}, 'sim_intercept_sensitivity_end': {'value': 3.860955652579378e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 80.70060639496586}, 'sim_slope_sensitivity_start': {'value': 0.02911713566266699}, 'sim_slope_sensitivity_end': {'value': 0.0009386273555315091}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 47.04900629761081}}}
# Cost function value is 0.1860669478430057, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1296.7098257610196}, 'sim_intercept_background_start': {'value': 0.08457740159267652}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 74.73661393547391}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.442103412430938e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4484788579131647e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 80.70060639496586}, 'sim_slope_sensitivity_start': {'value': 0.02911713566266699}, 'sim_slope_sensitivity_end': {'value': 0.0009386273555315091}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 47.04900629761081}}}
# Cost function value is 0.1860669347063815, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1296.7098257610196}, 'sim_intercept_background_start': {'value': 0.08457740159267652}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 74.73661393547391}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.442103412430938e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4484788579131647e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 87.73450771740704}, 'sim_slope_sensitivity_start': {'value': 0.02911713566266699}, 'sim_slope_sensitivity_end': {'value': 0.0009386273555315091}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 47.04900629761081}}}
# Cost function value is 0.18603014754276742, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1296.7098257610196}, 'sim_intercept_background_start': {'value': 0.08457740159267652}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 74.73661393547391}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.442103412430938e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4484788579131647e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 87.73450771740704}, 'sim_slope_sensitivity_start': {'value': 0.040711786831914745}, 'sim_slope_sensitivity_end': {'value': 0.0009386273555315091}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 54.67851207143713}}}
# Cost function value is 0.1860288597523421, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1296.7098254901832}, 'sim_intercept_background_start': {'value': 0.08457867618526646}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 74.73661392677376}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.442103412430938e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4484787271425753e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 87.73450771891379}, 'sim_slope_sensitivity_start': {'value': 0.04071178630591337}, 'sim_slope_sensitivity_end': {'value': 0.0009377880101117101}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 54.678513972140294}}}
# Cost function value is 0.18602791135149596, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1295.7290538826346}, 'sim_intercept_background_start': {'value': 0.08457867618526646}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 74.73661392677376}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.442103412430938e-08}, 'sim_intercept_sensitivity_end': {'value': 3.4484787271425753e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 87.73450771891379}, 'sim_slope_sensitivity_start': {'value': 0.04071178630591337}, 'sim_slope_sensitivity_end': {'value': 0.0009377880101117101}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 54.678513972140294}}}
# ...
# Cost function value is 0.24797225106332338, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 3069.811531432104}, 'sim_intercept_background_start': {'value': 0.09312091677768639}, 'sim_intercept_background_end': {'value': 0.011168045687215826}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 28.250467614376003}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 2.7230872893762626e-08}, 'sim_intercept_sensitivity_end': {'value': 2.2457007553213976e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 93.72257316106808}, 'sim_slope_sensitivity_start': {'value': 0.07875489693065137}, 'sim_slope_sensitivity_end': {'value': 0.0010955016050061867}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 22.88390865199406}}}
# Cost function value is 0.20828102227113918, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 3069.7660734416586}, 'sim_intercept_background_start': {'value': 1e-06}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 26.205407128325252}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 2.723087289426174e-08}, 'sim_intercept_sensitivity_end': {'value': 2.2418763583163838e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 93.72264785048891}, 'sim_slope_sensitivity_start': {'value': 0.07335457226168551}, 'sim_slope_sensitivity_end': {'value': 0.0009439556811850014}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 77.01373939610063}}}
# Cost function value is 0.2079551129647888, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 3069.7660734416586}, 'sim_intercept_background_start': {'value': 0.08756114822550418}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 57.33501156961335}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.0870137344300747e-08}, 'sim_intercept_sensitivity_end': {'value': 1.6436685981811026e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 93.72264785048891}, 'sim_slope_sensitivity_start': {'value': 0.07335457226168551}, 'sim_slope_sensitivity_end': {'value': 0.0009439556811850014}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 77.01373939610063}}}
# Cost function value is 0.20795497074602987, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 3069.7660734416586}, 'sim_intercept_background_start': {'value': 0.08756114822550418}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 57.33501156961335}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.0870137344300747e-08}, 'sim_intercept_sensitivity_end': {'value': 1.6436685981811026e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 27.130671801060384}, 'sim_slope_sensitivity_start': {'value': 0.09143847880704385}, 'sim_slope_sensitivity_end': {'value': 0.0009439556811850014}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 77.01373939610063}}}
# Cost function value is 0.2079247406409393, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 3069.766073087134}, 'sim_intercept_background_start': {'value': 0.08756041534909799}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 57.33501157600748}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.0870137344300747e-08}, 'sim_intercept_sensitivity_end': {'value': 1.643668586439096e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 27.13067180022807}, 'sim_slope_sensitivity_start': {'value': 0.09143847880624931}, 'sim_slope_sensitivity_end': {'value': 0.0009480121130580876}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 77.01373938845737}}}
# Cost function value is 0.20792468914452142, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 3069.766073087134}, 'sim_intercept_background_start': {'value': 0.06583014044135269}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 57.33501157600748}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.0870137344300747e-08}, 'sim_intercept_sensitivity_end': {'value': 1.643668586439096e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 27.13067180022807}, 'sim_slope_sensitivity_start': {'value': 0.09143847880624931}, 'sim_slope_sensitivity_end': {'value': 0.0009480121130580876}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 77.01373938845737}}}
# Cost function value is 0.20792468909689213, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 3069.766072601797}, 'sim_intercept_background_start': {'value': 0.0658291475041945}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 57.33501158538587}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 3.087013734406629e-08}, 'sim_intercept_sensitivity_end': {'value': 1.643668565173611e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 27.130671803744963}, 'sim_slope_sensitivity_start': {'value': 0.09143847880507701}, 'sim_slope_sensitivity_end': {'value': 0.0009480177682278922}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 77.01373938494046}}}
# Cost function value is 0.20744410031802815, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1066.6445927501481}, 'sim_intercept_background_start': {'value': 0.02485732313135411}, 'sim_intercept_background_end': {'value': 0.0015322338458352003}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 63.44532412827646}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.281066558012063e-08}, 'sim_intercept_sensitivity_end': {'value': 1.2522496828897557e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 93.46624604602424}, 'sim_slope_sensitivity_start': {'value': 0.03676703428806099}, 'sim_slope_sensitivity_end': {'value': 0.0009252642264995646}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 79.53793188487458}}}
# Cost function value is 0.205536071335402, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 1066.6445923797703}, 'sim_intercept_background_start': {'value': 0.024856230555635926}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 63.44532413221272}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 8.281066558012063e-08}, 'sim_intercept_sensitivity_end': {'value': 1.2522496812475818e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 93.46624604608367}, 'sim_slope_sensitivity_start': {'value': 0.03676703430529891}, 'sim_slope_sensitivity_end': {'value': 0.000937949519845571}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 79.53793182330413}}}
# Cost function value is 0.2049720249975539, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 291.26568301481893}, 'sim_intercept_background_start': {'value': 0.09094466593603515}, 'sim_intercept_background_end': {'value': 0.00029803432442601543}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 88.19233315503809}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 1.830110975631503e-08}, 'sim_intercept_sensitivity_end': {'value': 2.9409324717359323e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 7.110473408804461}, 'sim_slope_sensitivity_start': {'value': 0.0011918626954501464}, 'sim_slope_sensitivity_end': {'value': 0.0008721981772562483}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 0.8612858076414176}}}
# Cost function value is 0.20496944554455568, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 291.26568301481893}, 'sim_intercept_background_start': {'value': 0.05476475335743644}, 'sim_intercept_background_end': {'value': 0.00029803432442601543}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 46.79879992879284}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 1.830110975631503e-08}, 'sim_intercept_sensitivity_end': {'value': 2.9409324717359323e-08}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 7.110473408804461}, 'sim_slope_sensitivity_start': {'value': 0.0011918626954501464}, 'sim_slope_sensitivity_end': {'value': 0.0008721981772562483}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 0.8612858076414176}}}
# Cost function value is 0.20439451993028096, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 291.26568301481893}, 'sim_intercept_background_start': {'value': 0.05476475335743644}, 'sim_intercept_background_end': {'value': 0.00029803432442601543}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 46.79879992879284}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.099598694246331e-08}, 'sim_intercept_sensitivity_end': {'value': 9.046428590774304e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 7.110473408804461}, 'sim_slope_sensitivity_start': {'value': 0.0011918626954501464}, 'sim_slope_sensitivity_end': {'value': 0.0008721981772562483}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 0.8612858076414176}}}
# Cost function value is 0.20433615720934983, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 291.26568301481893}, 'sim_intercept_background_start': {'value': 0.05476475335743644}, 'sim_intercept_background_end': {'value': 0.00029803432442601543}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 46.79879992879284}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.099598694246331e-08}, 'sim_intercept_sensitivity_end': {'value': 9.046428590774304e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 86.56474203399273}, 'sim_slope_sensitivity_start': {'value': 0.0011918626954501464}, 'sim_slope_sensitivity_end': {'value': 0.0008721981772562483}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 0.8612858076414176}}}
# Cost function value is 0.20292873752221433, and parameters are {'background': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_slope_background': {'value': 291.26566974462054}, 'sim_intercept_background_start': {'value': 0.055302777869130404}, 'sim_intercept_background_end': {'value': 1e-06}, 'sim_intercept_background_a': {'value': 1}, 'sim_intercept_background_loc': {'value': 0}, 'sim_intercept_background_beta': {'value': 46.79879674754535}}, 'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'}, 'sim_intercept_sensitivity_start': {'value': 5.099598694246331e-08}, 'sim_intercept_sensitivity_end': {'value': 9.046421610393074e-09}, 'sim_intercept_sensitivity_a': {'value': 1}, 'sim_intercept_sensitivity_loc': {'value': 0}, 'sim_intercept_sensitivity_beta': {'value': 86.56474206830906}, 'sim_slope_sensitivity_start': {'value': 0.001140163475405043}, 'sim_slope_sensitivity_end': {'value': 0.0009051160734064661}, 'sim_slope_sensitivity_a': {'value': 1}, 'sim_slope_sensitivity_loc': {'value': 0}, 'sim_slope_sensitivity_beta': {'value': 0.8720695319768966}}}

# %%
all_optim_params
# Out:
# {'channel_1': {'background': {'feature_schema': {'mag_1007': 'mag1_1007'},
#    'sim_slope_background': {'value': 10.336598824035145},
#    'sim_intercept_background_start': {'value': 0.07257098707691573},
#    'sim_intercept_background_end': {'value': 1e-06},
#    'sim_intercept_background_a': {'value': 1},
#    'sim_intercept_background_loc': {'value': 0},
#    'sim_intercept_background_beta': {'value': 21.99609273358217}},
#   'sensitivity': {'feature_schema': {'mag_1007': 'mag1_1007'},
#    'sim_intercept_sensitivity_start': {'value': 5.971203240106872e-08},
#    'sim_intercept_sensitivity_end': {'value': 9.998336028044808e-10},
#    'sim_intercept_sensitivity_a': {'value': 1},
#    'sim_intercept_sensitivity_loc': {'value': 0},
#    'sim_intercept_sensitivity_beta': {'value': 1.548852616929948},
#    'sim_slope_sensitivity_start': {'value': 0.033399396865616514},
#    'sim_slope_sensitivity_end': {'value': 0.0009298344390491388},
#    'sim_slope_sensitivity_a': {'value': 1},
#    'sim_slope_sensitivity_loc': {'value': 0},
#    'sim_slope_sensitivity_beta': {'value': 83.3741649199482}}},
#  'channel_3': {'background': {'feature_schema': {'mag_1007': 'mag3_1007'},
#    'sim_slope_background': {'value': 70.953698668192},
#    'sim_intercept_background_start': {'value': 0.1},
#    'sim_intercept_background_end': {'value': 1e-06},
#    'sim_intercept_background_a': {'value': 1},
#    'sim_intercept_background_loc': {'value': 0},
#    'sim_intercept_background_beta': {'value': 34.64984130463598}},
#   'sensitivity': {'feature_schema': {'mag_1007': 'mag3_1007'},
#    'sim_intercept_sensitivity_start': {'value': 3.70215573847937e-08},
#    'sim_intercept_sensitivity_end': {'value': 3.7166061387956526e-09},
#    'sim_intercept_sensitivity_a': {'value': 1},
#    'sim_intercept_sensitivity_loc': {'value': 0},
#    'sim_intercept_sensitivity_beta': {'value': 0.7578672543714248},
#    'sim_slope_sensitivity_start': {'value': 0.02863329393621516},
#    'sim_slope_sensitivity_end': {'value': 0.0009339001848848542},
#    'sim_slope_sensitivity_a': {'value': 1},
#    'sim_slope_sensitivity_loc': {'value': 0},
#    'sim_slope_sensitivity_beta': {'value': 95.91010056639469}}},
#  'channel_4': {'background': {'feature_schema': {'mag_1007': 'mag4_1007'},
#    'sim_slope_background': {'value': 291.26566974462054},
#    'sim_intercept_background_start': {'value': 0.055302777869130404},
#    'sim_intercept_background_end': {'value': 1e-06},
#    'sim_intercept_background_a': {'value': 1},
#    'sim_intercept_background_loc': {'value': 0},
#    'sim_intercept_background_beta': {'value': 46.79879674754535}},
#   'sensitivity': {'feature_schema': {'mag_1007': 'mag4_1007'},
#    'sim_intercept_sensitivity_start': {'value': 5.099598694246331e-08},
#    'sim_intercept_sensitivity_end': {'value': 9.046421610393074e-09},
#    'sim_intercept_sensitivity_a': {'value': 1},
#    'sim_intercept_sensitivity_loc': {'value': 0},
#    'sim_intercept_sensitivity_beta': {'value': 86.56474206830906},
#    'sim_slope_sensitivity_start': {'value': 0.001140163475405043},
#    'sim_slope_sensitivity_end': {'value': 0.0009051160734064661},
#    'sim_slope_sensitivity_a': {'value': 1},
#    'sim_slope_sensitivity_loc': {'value': 0},
#    'sim_slope_sensitivity_beta': {'value': 0.8720695319768966}}}}

# %%
with open (r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\all_optim_params.p','wb') as fp:
    pickle.dump(all_optim_params,fp)

# %%
# with open (r'C:\Users\lwang\OneDrive - Biolinq Inc\Gen 1\Algorithm Development\Gen 1 Model Optimization\20240521\all_optim_params.p','rb') as fp:
#     all_optim_params2 = pickle.load(fp)

# %%
all_results

# %%
all_optim_params

# %%
import scipy.stats as dist
dist_info_sim_slope = dist.gamma(a=16,loc=0,scale=1/7061)
time_from_start = [0,0.08,0.25,0.5,1,2,5]
sim_slope_sensitivity = 0 + 1*dist_info_sim_slope.cdf(time_from_start)
print(sim_slope_sensitivity)

# %%
result

# %%
import pprint
pp = pprint.PrettyPrinter(depth=4)
params_dict = params_list_to_dict(result.x,1)
pp.pprint(params_dict)

# %%
params = params_list_to_dict(result.x,ch_str)
g_train_hat, sensitivity = glucose_model(cur_train,features_train,params)    
mard = g_train_hat.sub(g_train).abs().div(g_train).mean()
error = g_train_hat.sub(g_train).mul(sensitivity).abs().div(g_train).mean()

# %%
mard

# %%
error

# %%
sim_slope = g_train.div(cur_train).div(features_train['mag1_1007']).mean()
sim_slope

# %%
g_simple = cur_train.mul(features_train['mag1_1007']).mul(sim_slope)
g_simple.sub(g_train).abs().div(g_train).mean()

# %%
reg_simple = LinearRegression().fit(g_train.values.reshape(-1,1), g_simple.values)
print(reg_simple.score(g_train.values.reshape(-1,1), g_simple.values))
print(reg_simple.coef_)
print(reg_simple.intercept_)

# %%
params = params_list_to_dict(result.x,ch_str)
g_hat_train, _ = glucose_model(cur_train,features_train,params) 
g_hat_test, _ = glucose_model(cur_test,features_test,params) 
reg_train = LinearRegression().fit(g_train.values.reshape(-1,1), g_hat_train.values)
print(reg_train.score(g_train.values.reshape(-1,1), g_hat_train.values))
print(reg_train.coef_)
print(reg_train.intercept_)
